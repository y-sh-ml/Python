# %%
len(df[df.duplicated(subset='customer_id')])

# %%
df = df.duplicated(subset='customer_id', keep=False)

# %% [markdown]
# ### 参考

# %% [markdown]
# ・[pandas.DataFrame, Seriesの重複した行を抽出・削除](https://note.nkmk.me/python-pandas-duplicated-drop-duplicates/)
