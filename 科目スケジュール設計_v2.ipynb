# %% [markdown]
# ## Input

# %% [markdown]
# `first_end`、`last_end` は木曜日に設定

# %%
month = 12
last_month = 12

first_start = 1
first_end = 4

last_start = 29
last_end = 1

# %% [markdown]
# ## Output

# %%
second_start = first_end + 4
second_end = second_start + 3
third_start = second_start + 7
third_end = third_start + 3
fourth_start = third_start + 7
fourth_end = fourth_start + 3
fifth_start = fourth_start + 7
fifth_end = fifth_start + 3

if month < 10:
  month = f'0{month}'
else:
  pass

if last_month < 10:
  last_month = f'0{last_month}'
else:
  pass

print(f'・{month}/0{first_start}-{month}/0{first_end}：')

if second_start < 10:
  start_zero = '0'
else:
  start_zero = ''

if second_end < 10:
  end_zero = '0'
else:
  end_zero = ''

print(f'・{month}/{start_zero}{second_start}-{month}/{end_zero}{second_end}：')

if third_start < 10:
  start_zero = '0'
else:
  start_zero = ''

print(f'・{month}/{start_zero}{third_start}-{month}/{third_end}：')
print(f'・{month}/{fourth_start}-{month}/{fourth_end}：')
print(f'・{month}/{last_start}-{month}/{last_end}：')
# Out:
# ・12/01-12/04：
# ・12/08-12/11：
# ・12/15-12/18：
# ・12/22-12/25：
# ・12/29-12/1：
